# %%
# Celda 1: Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/programador_quirurgico

# %%
# Celda 2: Instalar dependencias (incluye OR-Tools y DEAP para optimizador avanzado)
# !pip install -q gradio pandas numpy plotly scikit-learn ortools deap

# %%
# Celda 3: Ejecutar aplicación
# %run programador_quirurgico_colab_v49.py
