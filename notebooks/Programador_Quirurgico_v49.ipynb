# %%
# Celda 1: Clonar desde GitHub
# !rm -rf programador-quirurgico
# !git clone https://github.com/ikmanuelmelara/programador-quirurgico.git
# %cd programador-quirurgico
print("✓ Repositorio clonado - Rama:")
# !git branch --show-current

# %%
# Celda 2: Instalar dependencias con versiones compatibles
# !pip install -q gradio pandas numpy plotly scikit-learn ortools deap 'protobuf>=3.20.3,<6.0.0'

print("✓ Dependencias instaladas correctamente")

# %%
# Celda temporal: Explorar estructura del proyecto
print("📂 Directorio actual:")
# !pwd

print("\n📄 Archivos Python en raíz:")
# !ls -1 *.py 2>/dev/null || echo "No hay archivos .py en raíz"

print("\n📂 Contenido de carpeta 'app/':")
# !ls -1 app/*.py 2>/dev/null || echo "No hay carpeta app/"

print("\n📂 Contenido de carpeta 'src/':")
# !ls -1 src/*.py 2>/dev/null || echo "No hay carpeta src/"

print("\n📂 Contenido de carpeta 'notebooks/':")
# !ls -1 notebooks/ 2>/dev/null || echo "No hay carpeta notebooks/"
# Out:
# 📂 Directorio actual:
# /content/programador-quirurgico
#
# 📄 Archivos Python en raíz:
# setup.py
#
# 📂 Contenido de carpeta 'app/':
# app/programador_quirurgico_colab_v49.py
#
# 📂 Contenido de carpeta 'src/':
# src/config.py
# src/constraint_learning_advanced.py
# src/constraint_learning.py
# src/__init__.py
# src/main.py
# src/models.py
# src/optimizer_advanced.py
# src/optimizer.py
# src/predictor_demanda.py
# src/simulador_whatif.py
# src/synthetic_data.py
# src/urgencias_predictor.py
#
# 📂 Contenido de carpeta 'notebooks/':
# Programador_Quirurgico_v49.ipynb

# %%
# Celda 3: Ejecutar aplicación (con configuración de rutas)
import sys
import os

# Añadir rutas necesarias al PYTHONPATH
sys.path.insert(0, '/content/programador-quirurgico')
sys.path.insert(0, '/content/programador-quirurgico/app')
sys.path.insert(0, '/content/programador-quirurgico/src')

# Verificar rutas
print("✓ Rutas Python configuradas:")
print(f"  - {sys.path[0]}")
print(f"  - {sys.path[1]}")
print(f"  - {sys.path[2]}\n")

# Cambiar al directorio app
# %cd /content/programador-quirurgico/app

# Ejecutar aplicación
print("▶️ Ejecutando aplicación...\n")
# %run programador_quirurgico_colab_v49.py
